# %%
# !pip install pandasql
# !pip install openpyxl

import pandas as pd
import numpy as np
import unittest
from pandasql import sqldf 
from datetime import datetime
from datetime import date as dt
from datetime import time
from datetime import timedelta
import math
import sys
import re
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26784 sha256=b9d6ec9b8a1eec4e0098185ebbf5005b070fcc066e74ef43ff948e8c5db6295b
#   Stored in directory: /root/.cache/pip/wheels/63/e8/ec/75b1df467ecf57b6ececb32cb16f4e86697cbfe55cb0c51f07
# Successfully built pandasql
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 KB 14.0 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
########### Import ###########
df_area_geogr=pd.read_csv("/work/data_consolidada/datos_tabla/df_data_tabla_area_geogr.csv")
df_ciudades=pd.read_csv("/work/data_consolidada/datos_tabla/df_data_tabla_ciudades.csv")
#df_tabla_contenido=pd.read_csv("/work/data_consolidada/datos_tabla/df_data_tabla_contenido.csv")
df_edad_espect=pd.read_csv("/work/data_consolidada/datos_tabla/df_data_tabla_edad_espect.csv")
df_estado_suscripcion=pd.read_csv("/work/data_consolidada/datos_tabla/df_data_tabla_estado_suscripcion.csv")
df_fuente_trafico=pd.read_csv("/work/data_consolidada/datos_tabla/df_data_tabla_fuente_trafico.csv")
df_sexo_espect=pd.read_csv("/work/data_consolidada/datos_tabla/df_data_tabla_sexo_espect.csv")
df_tipo_dispositivo=pd.read_csv("/work/data_consolidada/datos_tabla/df_data_tabla_tipo_dispositivo.csv")
#df_priori=pd.read_excel("/work/data_consolidada/Priori_Data_info_videos.xlsx")
#df_polarity_videos=pd.read_excel("/work/Polarity Video.xlsx")
#df_polarity_comments=pd.read_excel("/work/polarity.xlsx")

# %%
df_ag = df_area_geogr.groupby(["area_geografica"]).size().reset_index(name='count')
df_ag["consecutivo"] = np.arange(len(df_ag))
print(df_ag) # 43 categ
# Out:
#    area_geografica  count  consecutivo
# 0               AO      1            0
# 1               AR     98            1
# 2               BD      2            2
# 3               BO     26            3
# 4               BR     33            4
# 5               CL     25            5
# 6               CO    100            6
# 7               CR      4            7
# 8               DE      1            8
# 9               DO     16            9
# 10              DZ      1           10
# 11              EC     30           11
# 12              ES     78           12
# 13              GT      8           13
# 14              HN     12           14
# 15              ID     14           15
# 16              IN     13           16
# 17              IQ      1           17
# 18              IT      1           18
# 19              JP      2           19
# 20              KH      3           20
# 21              KR      3           21
# 22              LA      1           22
# ...

# %%
df_area_geogr = df_area_geogr[['nombre_video', 'fecha_publicacion', 'area_geografica', 'visualizaciones'
        , 'tiempo_de_visualizacion_(horas)', 'duracion_media_de_las_visualizaciones']].merge(df_ag[['area_geografica'
        , 'consecutivo' ]], on=['area_geografica'], how='left')

print(df_area_geogr.dtypes)
# Out:
# nombre_video                              object
# fecha_publicacion                          int64
# area_geografica                           object
# visualizaciones                            int64
# tiempo_de_visualizacion_(horas)          float64
# duracion_media_de_las_visualizaciones     object
# consecutivo                                int64
# dtype: object

# %%
df_ciudades.dtypes
# Out:
# ciudades                                  object
# nombre_de_la_ciudad                       object
# visualizaciones                            int64
# tiempo_de_visualizacion_(horas)          float64
# duracion_media_de_las_visualizaciones     object
# fecha_publicacion                          int64
# nombre_video                              object
# dtype: object

# %%
df_nc = df_ciudades.groupby(["nombre_de_la_ciudad"]).size().reset_index(name='count')
df_nc["consecutivo"] = np.arange(len(df_nc))
print(df_nc) # 193 categ
# Out:
#     nombre_de_la_ciudad  count  consecutivo
# 0            9 de Julio      1            0
# 1              A Coruña      1            1
# 2                  Agra      1            2
# 3        Aguascalientes      3            3
# 4             Ahmedabad      1            4
# ..                  ...    ...          ...
# 189    Villa de Álvarez      1          189
# 190        Villahermosa      1          190
# 191             Yakarta      2          191
# 192          Yogyakarta      1          192
# 193             Águilas      1          193
#
# [194 rows x 3 columns]

# %%
df_ciudades = df_ciudades[['nombre_video', 'fecha_publicacion', 'ciudades', 'nombre_de_la_ciudad', 'visualizaciones'
        , 'tiempo_de_visualizacion_(horas)', 'duracion_media_de_las_visualizaciones']].merge(df_nc[['nombre_de_la_ciudad'
        , 'consecutivo' ]], on=['nombre_de_la_ciudad'], how='left')

print(df_ciudades.dtypes)
# Out:
# nombre_video                              object
# fecha_publicacion                          int64
# ciudades                                  object
# nombre_de_la_ciudad                       object
# visualizaciones                            int64
# tiempo_de_visualizacion_(horas)          float64
# duracion_media_de_las_visualizaciones     object
# consecutivo                              float64
# dtype: object

# %%
df_edad_espect.dtypes
# Out:
# edad_del_espectador                       object
# visualizaciones_(%)                      float64
# duracion_media_de_las_visualizaciones     object
# porcentaje_medio_visto_(%)               float64
# tiempo_de_visualizacion_(horas)_(%)      float64
# fecha_publicacion                          int64
# nombre_video                              object
# dtype: object

# %%
df_ed = df_edad_espect.groupby(["edad_del_espectador"]).size().reset_index(name='count')
df_ed["consecutivo"] = np.arange(len(df_ed))
print(df_ed) # 5 categ
# Out:
#   edad_del_espectador  count  consecutivo
# 0  Entre 13 y 17 años      1            0
# 1  Entre 18 y 24 años      9            1
# 2  Entre 25 y 34 años     58            2
# 3  Entre 35 y 44 años     61            3
# 4  Entre 45 y 54 años     42            4
# 5  Entre 55 y 64 años      9            5

# %%
df_edad_espect = df_edad_espect[['nombre_video', 'fecha_publicacion', 'edad_del_espectador', 'visualizaciones_(%)'
        , 'duracion_media_de_las_visualizaciones', 'porcentaje_medio_visto_(%)', 'tiempo_de_visualizacion_(horas)_(%)']].merge(df_ed[['edad_del_espectador'
        , 'consecutivo' ]], on=['edad_del_espectador'], how='left')

print(df_edad_espect.dtypes)
# Out:
# nombre_video                              object
# fecha_publicacion                          int64
# edad_del_espectador                       object
# visualizaciones_(%)                      float64
# duracion_media_de_las_visualizaciones     object
# porcentaje_medio_visto_(%)               float64
# tiempo_de_visualizacion_(horas)_(%)      float64
# consecutivo                                int64
# dtype: object

# %%
df_estado_suscripcion.dtypes
# Out:
# estado_de_suscripcion                     object
# visualizaciones                            int64
# tiempo_de_visualizacion_(horas)          float64
# duracion_media_de_las_visualizaciones     object
# fecha_publicacion                          int64
# nombre_video                              object
# dtype: object

# %%
df_es = df_estado_suscripcion.groupby(["estado_de_suscripcion"]).size().reset_index(name='count')
df_es["consecutivo"] = np.arange(len(df_es))
print(df_es) # 2 categ
# Out:
#   estado_de_suscripcion  count  consecutivo
# 0           No suscrito    105            0
# 1              Suscrito    105            1
# 2                 Total    105            2

# %%
df_estado_suscripcion = df_estado_suscripcion[['nombre_video', 'fecha_publicacion', 'estado_de_suscripcion', 'visualizaciones'
        ,'tiempo_de_visualizacion_(horas)', 'duracion_media_de_las_visualizaciones']].merge(df_es[['estado_de_suscripcion'
        , 'consecutivo' ]], on=['estado_de_suscripcion'], how='left')

print(df_estado_suscripcion.dtypes)
# Out:
# nombre_video                              object
# fecha_publicacion                          int64
# estado_de_suscripcion                     object
# visualizaciones                            int64
# tiempo_de_visualizacion_(horas)          float64
# duracion_media_de_las_visualizaciones     object
# consecutivo                                int64
# dtype: object

# %%
df_fuente_trafico.dtypes
# Out:
# fuente_de_trafico                              object
# visualizaciones                               float64
# tiempo_de_visualizacion_(horas)               float64
# duracion_media_de_las_visualizaciones          object
# impresiones                                   float64
# porcentaje_de_clics_de_las_impresiones_(%)    float64
# fecha_publicacion                               int64
# nombre_video                                   object
# dtype: object

# %%
df_ft = df_fuente_trafico.groupby(["fuente_de_trafico"]).size().reset_index(name='count')
df_ft["consecutivo"] = np.arange(len(df_ft))
print(df_ft) # 15 categ
# Out:
#                   fuente_de_trafico  count  consecutivo
# 0               Búsqueda de YouTube    106            0
# 1             Directa o desconocida    106            1
# 2                    Feed de Shorts     22            2
# 3                  Fuentes externas    106            3
# 4          Funciones de exploración    106            4
# 5            Listas de reproducción    106            5
# 6                    Notificaciones    106            6
# 7        Otras funciones de YouTube    105            7
# 8                 Pantallas finales     85            8
# 9             Publicidad de YouTube      1            9
# 10  Página de lista de reproducción    106           10
# 11                 Páginas de canal    106           11
# 12                Páginas de sonido      4           12
# 13  Tarjetas de vídeo y anotaciones     22           13
# 14                            Total    106           14
# 15                 Vídeos sugeridos    106           15

# %%
df_fuente_trafico = df_fuente_trafico[['nombre_video', 'fecha_publicacion', 'fuente_de_trafico', 'visualizaciones'
        ,'tiempo_de_visualizacion_(horas)', 'duracion_media_de_las_visualizaciones', 'impresiones'
        , 'porcentaje_de_clics_de_las_impresiones_(%)']].merge(df_ft[['fuente_de_trafico'
        , 'consecutivo' ]], on=['fuente_de_trafico'], how='left')

print(df_fuente_trafico.dtypes)
# Out:
# nombre_video                                   object
# fecha_publicacion                               int64
# fuente_de_trafico                              object
# visualizaciones                               float64
# tiempo_de_visualizacion_(horas)               float64
# duracion_media_de_las_visualizaciones          object
# impresiones                                   float64
# porcentaje_de_clics_de_las_impresiones_(%)    float64
# consecutivo                                     int64
# dtype: object

# %%
df_sexo_espect.dtypes
# Out:
# sexo_del_espectador                       object
# visualizaciones_(%)                      float64
# duracion_media_de_las_visualizaciones     object
# porcentaje_medio_visto_(%)               float64
# tiempo_de_visualizacion_(horas)_(%)      float64
# fecha_publicacion                          int64
# nombre_video                              object
# dtype: object

# %%
df_sx = df_sexo_espect.groupby(["sexo_del_espectador"]).size().reset_index(name='count')
df_sx["consecutivo"] = np.arange(len(df_sx))
print(df_sx) # 1 categ
# Out:
#   sexo_del_espectador  count  consecutivo
# 0              Hombre     84            0
# 1               Mujer      9            1

# %%
df_sexo_espect = df_sexo_espect[['nombre_video', 'fecha_publicacion', 'sexo_del_espectador', 'visualizaciones_(%)'
        , 'duracion_media_de_las_visualizaciones', 'porcentaje_medio_visto_(%)', 'tiempo_de_visualizacion_(horas)_(%)']].merge(df_sx[['sexo_del_espectador'
        , 'consecutivo' ]], on=['sexo_del_espectador'], how='left')

print(df_sexo_espect.dtypes)
# Out:
# nombre_video                              object
# fecha_publicacion                          int64
# sexo_del_espectador                       object
# visualizaciones_(%)                      float64
# duracion_media_de_las_visualizaciones     object
# porcentaje_medio_visto_(%)               float64
# tiempo_de_visualizacion_(horas)_(%)      float64
# consecutivo                                int64
# dtype: object

# %%
df_tipo_dispositivo.dtypes
# Out:
# tipo_de_dispositivo                       object
# visualizaciones                            int64
# tiempo_de_visualizacion_(horas)          float64
# duracion_media_de_las_visualizaciones     object
# fecha_publicacion                          int64
# nombre_video                              object
# dtype: object

# %%
df_td = df_tipo_dispositivo.groupby(["tipo_de_dispositivo"]).size().reset_index(name='count')
df_td["consecutivo"] = np.arange(len(df_td))
print(df_td) # 4 categ
# Out:
#   tipo_de_dispositivo  count  consecutivo
# 0           Ordenador    106            0
# 1                  TV    106            1
# 2              Tablet    106            2
# 3      Teléfono móvil    106            3
# 4               Total    106            4

# %%
df_tipo_dispositivo = df_tipo_dispositivo[['nombre_video', 'fecha_publicacion', 'tipo_de_dispositivo', 'visualizaciones'
        , 'tiempo_de_visualizacion_(horas)', 'duracion_media_de_las_visualizaciones']].merge(df_td[['tipo_de_dispositivo'
        , 'consecutivo' ]], on=['tipo_de_dispositivo'], how='left')

print(df_tipo_dispositivo.dtypes)
# Out:
# nombre_video                              object
# fecha_publicacion                          int64
# sexo_del_espectador                       object
# visualizaciones_(%)                      float64
# duracion_media_de_las_visualizaciones     object
# porcentaje_medio_visto_(%)               float64
# tiempo_de_visualizacion_(horas)_(%)      float64
# consecutivo                                int64
# dtype: object

# %%
########### Rename ###########
df_area_geogr.rename(columns = {'area_geografica':'area_geografica_AG', 'visualizaciones':'cnt_vis_AG', 
                'tiempo_de_visualizacion_(horas)':'tiempo_vis_AG', 
                'duracion_media_de_las_visualizaciones': 'duarcion_media_vis_AG'}, inplace = True)

df_ciudades.rename(columns = {'nombre_de_la_ciudad':'nombre_de_la_ciudad_NC', 'visualizaciones':'cnt_vis_NC', 
                'tiempo_de_visualizacion_(horas)':'tiempo_vis_NC', 
                'duracion_media_de_las_visualizaciones': 'duarcion_media_vis_NC'}, inplace = True)

df_edad_espect.rename(columns = {'edad_del_espectador':'rango_edad', 'duracion_media_de_las_visualizaciones':'duarcion_media_vis_edad'
                , 'visualizaciones_(%)': 'visualizaciones_(%)Edad'
                , 'tiempo_de_visualizacion_(horas)_(%)': 'tiempo_vis_(%)Edad'}
        , inplace = True)

df_estado_suscripcion.rename(columns = {'estado_de_suscripcion':'estado_de_suscripcion_ES', 'visualizaciones':'cnt_vis_ES', 
                'tiempo_de_visualizacion_(horas)':'tiempo_vis_ES', 
                'duracion_media_de_las_visualizaciones': 'duarcion_media_vis_ES'}, inplace = True)

df_fuente_trafico.rename(columns = {'fuente_de_trafico':'fuente_de_trafico_FT', 'visualizaciones':'cnt_vis_FT', 
                'tiempo_de_visualizacion_(horas)':'tiempo_vis_FT', 
                'duracion_media_de_las_visualizaciones': 'duarcion_media_vis_FT', 'impresiones': 'impresiones_FT'
                ,'porcentaje_de_clics_de_las_impresiones_(%)': 'porcentaje_clics_de_impr_FT'}, inplace = True)

df_sexo_espect.rename(columns = {'duracion_media_de_las_visualizaciones':'duarcion_media_vis_sexo'
                , 'visualizaciones_(%)': 'visualizaciones_(%)Sexo'
                , 'tiempo_de_visualizacion_(horas)_(%)': 'tiempo_vis_(%)Sexo'}
        , inplace = True)

df_tipo_dispositivo.rename(columns = {'tipo_de_dispositivo':'tipo_de_dispositivo_TD', 'visualizaciones':'cnt_vis_TD', 
                'tiempo_de_visualizacion_(horas)':'tiempo_vis_TD', 
                'duracion_media_de_las_visualizaciones': 'duarcion_media_vis_TD'}, inplace = True)

print(df_tipo_dispositivo.dtypes)
# Out:
# nombre_video               object
# fecha_publicacion           int64
# tipo_de_dispositivo_TD     object
# cnt_vis_TD                  int64
# tiempo_vis_TD             float64
# duarcion_media_vis_TD      object
# consecutivo                 int64
# dtype: object

# %%
##### Consecutivos
df_cons = [item for item in range(193)]
df_cons = pd.Series(df_cons).to_frame('consecutivo_gnral')
df_cons.dtypes
# Out:
# consecutivo_gnral    int64
# dtype: object

# %%
df_agr = df_ciudades.groupby(["nombre_video","fecha_publicacion"]).count().reset_index()
print(df_agr)
# Out:
#                                           nombre_video  fecha_publicacion  \
# 0        CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# 1    CorelDRAW MAGIC ››Text EFFECT‹‹ 🌟 TIPS Tutorial ▶           20210902
# 2    Cómo CONVERTIR CLIPS DE VIDEO a GIF ANIMADOS ...           20210601
# 3    Cómo CREAR una TARJETA de NEGOCIOS VIRTUAL 💳 ...           20210525
# 4    Estas son las ÚLTIMAS NOVEDADES de COREL DRAW...           20220427
# ..                                                 ...                ...
# 101  🧐 La TABLETA GRÁFICA más BARATA y VENDIDA ¿M...           20211111
# 102  🧐 PRESTA mucha ATENCIÓN a estos DETALLES para...           20220120
# 103  🧐 Sigue ESTE ORDEN en tus PROYECTOS ⭐ para CRE...           20220303
# 104  🧐 Te ENSEÑO estas TÉCNICAS de DIBUJO para DI...           20211109
# 105  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...           20210914
#
#      ciudades  nombre_de_la_ciudad_NC  cnt_vis_NC  tiempo_vis_NC  \
# ...

# %%
df_cons['joincol'] = 1
df_agr['joincol'] = 1

# %%
df_agr.head()
# Out:
#                                         nombre_video  fecha_publicacion  \
# 0      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# 1  CorelDRAW MAGIC ››Text EFFECT‹‹ 🌟 TIPS Tutorial ▶           20210902
# 2  Cómo CONVERTIR CLIPS DE VIDEO a GIF ANIMADOS ...           20210601
# 3  Cómo CREAR una TARJETA de NEGOCIOS VIRTUAL 💳 ...           20210525
# 4  Estas son las ÚLTIMAS NOVEDADES de COREL DRAW...           20220427
#
#    ciudades  nombre_de_la_ciudad_NC  cnt_vis_NC  tiempo_vis_NC  \
# 0         1                       0           1              1
# 1         6                       5           6              6
# 2         1                       0           1              1
# 3         3                       2           3              3
# 4         5                       4           5              5
#
#    duarcion_media_vis_NC  consecutivo  joincol
# 0                      1            0        1
# 1                      4            5        1
# ...

# %%
df = pd.merge(left=df_agr,right=df_cons, on='joincol', how='outer')

# %%
df.dtypes
# Out:
# nombre_video              object
# fecha_publicacion          int64
# ciudades                   int64
# nombre_de_la_ciudad_NC     int64
# cnt_vis_NC                 int64
# tiempo_vis_NC              int64
# duarcion_media_vis_NC      int64
# consecutivo                int64
# joincol                    int64
# consecutivo_gnral          int64
# dtype: object

# %%
########### Rename ###########
df=df[['nombre_video', 'fecha_publicacion', 'consecutivo_gnral']]
df.rename(columns = {'consecutivo_gnral':'consecutivo'}, inplace = True)
df
# Out:
#                                             nombre_video  fecha_publicacion  \
# 0          CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# 1          CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# 2          CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# 3          CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# 4          CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# ...                                                  ...                ...
# 20453  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...           20210914
# 20454  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...           20210914
# 20455  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...           20210914
# 20456  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...           20210914
# 20457  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...           20210914
#
#        consecutivo
# 0                0
# ...

# %%
df.groupby(["nombre_video","fecha_publicacion"]).count()
# Out:
#                                                                       consecutivo
# nombre_video                                       fecha_publicacion
# CÓMO VECTORIZAR PAISAJES_ Tutorial práctico      20210722                   193
# CorelDRAW MAGIC ››Text EFFECT‹‹ 🌟 TIPS Tutorial ▶  20210902                   193
# Cómo CONVERTIR CLIPS DE VIDEO a GIF ANIMADOS u... 20210601                   193
# Cómo CREAR una TARJETA de NEGOCIOS VIRTUAL 💳 P... 20210525                   193
# Estas son las ÚLTIMAS NOVEDADES de COREL DRAW ... 20220427                   193
# ...                                                                           ...
# 🧐 La TABLETA GRÁFICA más BARATA y VENDIDA ¿Me... 20211111                   193
# 🧐 PRESTA mucha ATENCIÓN a estos DETALLES para ... 20220120                   193
# 🧐 Sigue ESTE ORDEN en tus PROYECTOS ⭐ para CREA... 20220303                   193
# 🧐 Te ENSEÑO estas TÉCNICAS de DIBUJO para DIS... 20211109                   193
# ...

# %%
df.shape
# Out:
# (20458, 3)

# %%
########### Merge ###########
df_data_set = df[['nombre_video', 'fecha_publicacion','consecutivo']].merge(df_ciudades[['nombre_video', 'fecha_publicacion', 'consecutivo', 'nombre_de_la_ciudad_NC', 'cnt_vis_NC'
        , 'tiempo_vis_NC', 'duarcion_media_vis_NC' ]], on=['nombre_video', 'fecha_publicacion','consecutivo'], how='left')
df_data_set
# Out:
#                                             nombre_video  fecha_publicacion  \
# 0          CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# 1          CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# 2          CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# 3          CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# 4          CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# ...                                                  ...                ...
# 20454  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...           20210914
# 20455  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...           20210914
# 20456  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...           20210914
# 20457  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...           20210914
# 20458  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...           20210914
#
# ...

# %%
df_data_set = df_data_set[['consecutivo', 'nombre_video', 'fecha_publicacion', 'nombre_de_la_ciudad_NC', 'cnt_vis_NC'
        , 'tiempo_vis_NC', 'duarcion_media_vis_NC']].merge(df_area_geogr[['nombre_video', 'fecha_publicacion', 'consecutivo', 'area_geografica_AG', 'cnt_vis_AG'
        , 'tiempo_vis_AG', 'duarcion_media_vis_AG']], on=['nombre_video','fecha_publicacion', 'consecutivo'], how='left')
df_data_set
# Out:
#        consecutivo                                       nombre_video  \
# 0                0      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 1                1      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 2                2      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 3                3      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 4                4      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# ...            ...                                                ...
# 20454          188  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20455          189  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20456          190  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20457          191  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20458          192  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
#
#        fecha_publicacion nombre_de_la_ciudad_NC  cnt_vis_NC  tiempo_vis_NC  \
# ...

# %%
df_data_set = df_data_set[['consecutivo', 'nombre_video', 'fecha_publicacion', 'nombre_de_la_ciudad_NC', 'cnt_vis_NC'
        , 'tiempo_vis_NC', 'duarcion_media_vis_NC', 'area_geografica_AG', 'cnt_vis_AG'
        , 'tiempo_vis_AG', 'duarcion_media_vis_AG']].merge(df_edad_espect[['nombre_video'
        , 'fecha_publicacion', 'consecutivo', 'rango_edad', 'visualizaciones_(%)Edad', 'tiempo_vis_(%)Edad', 'duarcion_media_vis_edad' ]]
        , on=['nombre_video','fecha_publicacion', 'consecutivo'], how='left')
df_data_set
# Out:
#        consecutivo                                       nombre_video  \
# 0                0      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 1                1      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 2                2      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 3                3      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 4                4      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# ...            ...                                                ...
# 20454          188  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20455          189  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20456          190  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20457          191  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20458          192  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
#
#        fecha_publicacion nombre_de_la_ciudad_NC  cnt_vis_NC  tiempo_vis_NC  \
# ...

# %%
df_data_set = df_data_set[['consecutivo', 'nombre_video', 'fecha_publicacion', 'nombre_de_la_ciudad_NC', 'cnt_vis_NC'
        , 'tiempo_vis_NC', 'duarcion_media_vis_NC', 'area_geografica_AG', 'cnt_vis_AG'
        , 'tiempo_vis_AG', 'duarcion_media_vis_AG', 'rango_edad', 'visualizaciones_(%)Edad', 'tiempo_vis_(%)Edad', 'duarcion_media_vis_edad']].merge(df_estado_suscripcion[['nombre_video', 'fecha_publicacion', 'consecutivo'
        , 'estado_de_suscripcion_ES', 'cnt_vis_ES', 'tiempo_vis_ES', 'duarcion_media_vis_ES' ]], on=['nombre_video','fecha_publicacion'
        , 'consecutivo'], how='left')
df_data_set
# Out:
#        consecutivo                                       nombre_video  \
# 0                0      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 1                1      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 2                2      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 3                3      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 4                4      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# ...            ...                                                ...
# 20454          188  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20455          189  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20456          190  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20457          191  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20458          192  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
#
#        fecha_publicacion nombre_de_la_ciudad_NC  cnt_vis_NC  tiempo_vis_NC  \
# ...

# %%
df_data_set = df_data_set[['consecutivo', 'nombre_video', 'fecha_publicacion', 'nombre_de_la_ciudad_NC', 'cnt_vis_NC'
        , 'tiempo_vis_NC', 'duarcion_media_vis_NC', 'area_geografica_AG', 'cnt_vis_AG'
        , 'tiempo_vis_AG', 'duarcion_media_vis_AG', 'rango_edad', 'visualizaciones_(%)Edad', 'tiempo_vis_(%)Edad', 'duarcion_media_vis_edad'
        , 'estado_de_suscripcion_ES', 'cnt_vis_ES', 'tiempo_vis_ES', 'duarcion_media_vis_ES']].merge(df_fuente_trafico[['nombre_video', 'fecha_publicacion', 'consecutivo', 'fuente_de_trafico_FT'
        , 'cnt_vis_FT', 'tiempo_vis_FT', 'duarcion_media_vis_FT', 'impresiones_FT', 'porcentaje_clics_de_impr_FT' ]], on=['nombre_video','fecha_publicacion'
        , 'consecutivo'], how='left')
df_data_set
# Out:
#        consecutivo                                       nombre_video  \
# 0                0      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 1                1      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 2                2      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 3                3      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 4                4      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# ...            ...                                                ...
# 20454          188  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20455          189  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20456          190  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20457          191  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20458          192  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
#
#        fecha_publicacion nombre_de_la_ciudad_NC  cnt_vis_NC  tiempo_vis_NC  \
# ...

# %%
df_data_set = df_data_set[['consecutivo', 'nombre_video', 'fecha_publicacion', 'nombre_de_la_ciudad_NC', 'cnt_vis_NC'
        , 'tiempo_vis_NC', 'duarcion_media_vis_NC', 'area_geografica_AG', 'cnt_vis_AG'
        , 'tiempo_vis_AG', 'duarcion_media_vis_AG', 'rango_edad', 'visualizaciones_(%)Edad', 'tiempo_vis_(%)Edad', 'duarcion_media_vis_edad'
        , 'estado_de_suscripcion_ES', 'cnt_vis_ES', 'tiempo_vis_ES', 'duarcion_media_vis_ES', 'fuente_de_trafico_FT'
        , 'cnt_vis_FT', 'tiempo_vis_FT', 'duarcion_media_vis_FT', 'impresiones_FT', 'porcentaje_clics_de_impr_FT']].merge(df_sexo_espect[['nombre_video', 'fecha_publicacion', 'consecutivo', 'sexo_del_espectador'
        , 'visualizaciones_(%)Sexo', 'tiempo_vis_(%)Sexo', 'duarcion_media_vis_sexo' ]]
        , on=['nombre_video','fecha_publicacion', 'consecutivo'], how='left')
df_data_set
# Out:
#        consecutivo                                       nombre_video  \
# 0                0      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 1                1      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 2                2      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 3                3      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 4                4      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# ...            ...                                                ...
# 20454          188  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20455          189  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20456          190  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20457          191  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20458          192  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
#
#        fecha_publicacion nombre_de_la_ciudad_NC  cnt_vis_NC  tiempo_vis_NC  \
# ...

# %%
df_data_set = df_data_set[['consecutivo', 'nombre_video', 'fecha_publicacion', 'nombre_de_la_ciudad_NC', 'cnt_vis_NC'
        , 'tiempo_vis_NC', 'duarcion_media_vis_NC', 'area_geografica_AG', 'cnt_vis_AG'
        , 'tiempo_vis_AG', 'duarcion_media_vis_AG', 'rango_edad', 'visualizaciones_(%)Edad', 'tiempo_vis_(%)Edad', 'duarcion_media_vis_edad'
        , 'estado_de_suscripcion_ES', 'cnt_vis_ES', 'tiempo_vis_ES', 'duarcion_media_vis_ES', 'fuente_de_trafico_FT'
        , 'cnt_vis_FT', 'tiempo_vis_FT', 'duarcion_media_vis_FT', 'impresiones_FT', 'porcentaje_clics_de_impr_FT', 'sexo_del_espectador'
        , 'visualizaciones_(%)Sexo', 'tiempo_vis_(%)Sexo', 'duarcion_media_vis_sexo']].merge(df_tipo_dispositivo[['nombre_video', 'fecha_publicacion', 'consecutivo'
        , 'tipo_de_dispositivo_TD', 'cnt_vis_TD', 'tiempo_vis_TD', 'duarcion_media_vis_TD']], on=['nombre_video','fecha_publicacion'
        , 'consecutivo'], how='left') 
df_data_set
# Out:
#        consecutivo                                       nombre_video  \
# 0                0      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 1                1      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 2                2      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 3                3      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 4                4      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# ...            ...                                                ...
# 20454          188  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20455          189  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20456          190  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20457          191  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20458          192  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
#
#        fecha_publicacion nombre_de_la_ciudad_NC  cnt_vis_NC  tiempo_vis_NC  \
# ...

# %%
df_data_set.dtypes
# Out:
# consecutivo                      int64
# nombre_video                    object
# fecha_publicacion                int64
# nombre_de_la_ciudad_NC          object
# cnt_vis_NC                     float64
# tiempo_vis_NC                  float64
# duarcion_media_vis_NC           object
# area_geografica_AG              object
# cnt_vis_AG                     float64
# tiempo_vis_AG                  float64
# duarcion_media_vis_AG           object
# rango_edad                      object
# visualizaciones_(%)Edad        float64
# tiempo_vis_(%)Edad             float64
# duarcion_media_vis_edad         object
# estado_de_suscripcion_ES        object
# cnt_vis_ES                     float64
# tiempo_vis_ES                  float64
# duarcion_media_vis_ES           object
# fuente_de_trafico_FT            object
# cnt_vis_FT                     float64
# tiempo_vis_FT                  float64
# duarcion_media_vis_FT           object
# impresiones_FT                 float64
# ...

# %%
df_data_set.shape
# Out:
# (20459, 33)

# %%
#df_data_set
df_data_set.sort_values(by=['nombre_video', 'fecha_publicacion', 'consecutivo'], na_position='last')
# Out:
#        consecutivo                                       nombre_video  \
# 0                0      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 1                1      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 2                2      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 3                3      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# 4                4      CÓMO VECTORIZAR PAISAJES_ Tutorial práctico
# ...            ...                                                ...
# 20454          188  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20455          189  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20456          190  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20457          191  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
# 20458          192  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...
#
#        fecha_publicacion nombre_de_la_ciudad_NC  cnt_vis_NC  tiempo_vis_NC  \
# ...

# %%
df_data_set.groupby(["nombre_video"])["fecha_publicacion"].count()
# Out:
# nombre_video
# CÓMO VECTORIZAR PAISAJES_ Tutorial práctico                                            193
# CorelDRAW MAGIC ››Text EFFECT‹‹ 🌟 TIPS Tutorial ▶                                        193
# Cómo CONVERTIR CLIPS DE VIDEO a GIF ANIMADOS usando Vegas PRO                           193
# Cómo CREAR una TARJETA de NEGOCIOS VIRTUAL 💳 PASO a PASO ▶ Tutorial CorelDRAW (2021)    193
# Estas son las ÚLTIMAS NOVEDADES de COREL DRAW 2022                                      193
#                                                                                         ...
# 🧐 La TABLETA GRÁFICA más BARATA y VENDIDA ¿Merece la pena_ Review VEIKK S640           193
# 🧐 PRESTA mucha ATENCIÓN a estos DETALLES para DISEÑAR LOGOS en CorelDRAW 😱             193
# 🧐 Sigue ESTE ORDEN en tus PROYECTOS ⭐ para CREAR LOGOS ASÍ en CorelDRAW                 193
# 🧐 Te ENSEÑO estas TÉCNICAS de DIBUJO para DISEÑAR en CorelDRAW 🏠 ► TUTORIAL           193
# ...

# %%
df_data_set.to_excel('Delcavideograpghy_Consolidado.xlsx')

# %% [markdown]
# # Estructura Variables a Priori

# %%
########### Import ###########
df_tabla_contenido=pd.read_csv("/work/data_consolidada/datos_tabla/df_data_tabla_contenido.csv")
df_priori=pd.read_excel("/work/data_consolidada/Priori_Data_info_videos.xlsx")
df_polarity_videos=pd.read_excel("/work/Polarity Video.xlsx")
df_polarity_comments=pd.read_excel("/work/polarity.xlsx")

# %%
df_priori.columns
# Out:
# Index(['nombre_video_original', 'nombre_video', 'info_videos',
#        'duracion_video', 'page_links', 'id', 'dateCreated', 'likes',
#        'dislikes', 'rating', 'viewCount', 'Descargas?', 'Tema',
#        'Cant_Recomendaciones', 'Tiempo_Recomendación1',
#        'Tiempo_Recomendación2', 'Tiempo_Recomendación3', 'Publicidad_inicio',
#        'Publicidad_fin', 'Cant_Publicidad_durante', 'Tiempo_Publicidad_1',
#        'Tiempo_Publicidad_2', 'Tiempo_Publicidad_3', 'Tiempo_Publicidad_4',
#        'Tiempo_Publicidad_5', 'Tiempo_Publicidad_6', 'Tiempo_Publicidad_7',
#        'Tiempo_Publicidad_8', 'Polarity'],
#       dtype='object')

# %%
df_priori[df_priori['duracion_video'] != 'shorts']
# Out:
#                                  nombre_video_original nombre_video  \
# 0         💚Herramienta DIBUJO en Corel DRAW ▶ TUTORIAL          NaN
# 1    💚 TODO sobre la herramienta CURVA en CorelDRAW...          NaN
# 2    🏃🏼‍♂️ Speedrun LOGO CANGREJO #shorts ▶ DelcaVi...          NaN
# 3    ⭐ Haz tus DISEÑOS con PROPORCIÓN ÁUERA ▶ Tutor...          NaN
# 4    💚 La herramienta ZOOM Explicada ▶ TUTORIAL Cor...          NaN
# ..                                                 ...          ...
# 528               El baño del gato de DelcaVideography          NaN
# 529  Bancolombia, Medellín, Building, rascasuelos, ...          NaN
# 530  Edificio Bancolombia Medellín de DelcaVideography          NaN
# 531  DUCON sistemas modulares para oficina de Delca...          NaN
# 532                         SICORH de DelcaVideography          NaN
#
#                                           info_videos  \
# 0          5 días 8 minutos y 50 segundos 784 visitas
# ...

# %%
df_priori = df_priori[df_priori['duracion_video'].notna()]
df_priori = df_priori[df_priori['duracion_video'] != 'Shorts']

df_priori
# Out:
#                                  nombre_video_original nombre_video  \
# 0         💚Herramienta DIBUJO en Corel DRAW ▶ TUTORIAL          NaN
# 1    💚 TODO sobre la herramienta CURVA en CorelDRAW...          NaN
# 2    🏃🏼‍♂️ Speedrun LOGO CANGREJO #shorts ▶ DelcaVi...          NaN
# 3    ⭐ Haz tus DISEÑOS con PROPORCIÓN ÁUERA ▶ Tutor...          NaN
# 4    💚 La herramienta ZOOM Explicada ▶ TUTORIAL Cor...          NaN
# ..                                                 ...          ...
# 528               El baño del gato de DelcaVideography          NaN
# 529  Bancolombia, Medellín, Building, rascasuelos, ...          NaN
# 530  Edificio Bancolombia Medellín de DelcaVideography          NaN
# 531  DUCON sistemas modulares para oficina de Delca...          NaN
# 532                         SICORH de DelcaVideography          NaN
#
#                                           info_videos  \
# 0          5 días 8 minutos y 50 segundos 784 visitas
# ...

# %%
df_priori['duracion_video'] = df_priori['duracion_video'].apply(lambda cell: re.findall(r'\d+', cell))
df_priori['duracion_video'] = df_priori['duracion_video'].apply(lambda cell: 
time(hour=0, minute=int(cell[0]), second=int(cell[1]), microsecond=0) if len(cell)==2 else 
time(hour=0, minute=int(cell[0]), second=0, microsecond=0))

df_priori
# Out:
#                                  nombre_video_original nombre_video  \
# 0         💚Herramienta DIBUJO en Corel DRAW ▶ TUTORIAL          NaN
# 1    💚 TODO sobre la herramienta CURVA en CorelDRAW...          NaN
# 2    🏃🏼‍♂️ Speedrun LOGO CANGREJO #shorts ▶ DelcaVi...          NaN
# 3    ⭐ Haz tus DISEÑOS con PROPORCIÓN ÁUERA ▶ Tutor...          NaN
# 4    💚 La herramienta ZOOM Explicada ▶ TUTORIAL Cor...          NaN
# ..                                                 ...          ...
# 528               El baño del gato de DelcaVideography          NaN
# 529  Bancolombia, Medellín, Building, rascasuelos, ...          NaN
# 530  Edificio Bancolombia Medellín de DelcaVideography          NaN
# 531  DUCON sistemas modulares para oficina de Delca...          NaN
# 532                         SICORH de DelcaVideography          NaN
#
#                                           info_videos duracion_video  \
# 0          5 días 8 minutos y 50 segundos 784 visitas       00:08:50
# ...

# %%
########### Rename ###########
#df_priori2=df_priori2[['nombre_video', 'duracion_video']]
#df_priori2.rename(columns = {'duracion_video':'duracion_video2'}, inplace = True)
#df_priori2

# %%
#df_priori['duracion_video'] = df_priori['duracion_video'].apply(lambda cell: re.findall(r'\d+', cell))
#df_priori['duracion_video'] = df_priori['duracion_video'].apply(lambda cell: 
#time(hour=0, minute=int(cell[0]), second=int(cell[1]), microsecond=0) if len(cell)==2 else 
#time(hour=0, minute=int(cell[0]), second=0, microsecond=0))
#df_priori

# %%
df_agr=df_agr[['nombre_video', 'fecha_publicacion']]
df_agr
# Out:
#                                           nombre_video  fecha_publicacion
# 0        CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# 1    CorelDRAW MAGIC ››Text EFFECT‹‹ 🌟 TIPS Tutorial ▶           20210902
# 2    Cómo CONVERTIR CLIPS DE VIDEO a GIF ANIMADOS ...           20210601
# 3    Cómo CREAR una TARJETA de NEGOCIOS VIRTUAL 💳 ...           20210525
# 4    Estas son las ÚLTIMAS NOVEDADES de COREL DRAW...           20220427
# ..                                                 ...                ...
# 101  🧐 La TABLETA GRÁFICA más BARATA y VENDIDA ¿M...           20211111
# 102  🧐 PRESTA mucha ATENCIÓN a estos DETALLES para...           20220120
# 103  🧐 Sigue ESTE ORDEN en tus PROYECTOS ⭐ para CRE...           20220303
# 104  🧐 Te ENSEÑO estas TÉCNICAS de DIBUJO para DI...           20211109
# 105  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...           20210914
#
# [106 rows x 2 columns]

# %%
df_tc = df_tabla_contenido.groupby(["contenido"]).size().reset_index(name='count')
df_tc["consecutivo"] = np.arange(len(df_tc))
print(df_tc) # 0 categ
# Out:
#   contenido  count  consecutivo
# 0     Total    106            0

# %%
df_tabla_contenido.head()
# Out:
#   contenido  visualizaciones  tiempo_de_visualizacion_(horas)  suscriptores  \
# 0     Total            13062                         589.1126           195
# 1     Total             1675                          90.6025            11
# 2     Total             1796                          89.6495             4
# 3     Total             5936                         243.6388            28
# 4     Total              961                          36.8612             4
#
#    tus_ingresos_estimados_(usd)  impresiones  \
# 0                        12.261       428666
# 1                         2.262        42833
# 2                         3.343        71595
# 3                         5.957        67760
# 4                         1.621        42811
#
#    porcentaje_de_clics_de_las_impresiones_(%)  fecha_publicacion  \
# 0                                        1.16           20220118
# 1                                        1.47           20210930
# ...

# %%
df_tabla_contenido.dtypes
# Out:
# contenido                                      object
# visualizaciones                                 int64
# tiempo_de_visualizacion_(horas)               float64
# suscriptores                                    int64
# tus_ingresos_estimados_(usd)                  float64
# impresiones                                     int64
# porcentaje_de_clics_de_las_impresiones_(%)    float64
# fecha_publicacion                               int64
# nombre_video                                   object
# dtype: object

# %%
df_datos_priori = df_agr[['nombre_video', 'fecha_publicacion']].merge(df_tabla_contenido[['nombre_video', 'fecha_publicacion'
        ,'visualizaciones', 'tiempo_de_visualizacion_(horas)', 'suscriptores', 'tus_ingresos_estimados_(usd)'
        , 'impresiones', 'porcentaje_de_clics_de_las_impresiones_(%)' ]], on=['nombre_video', 'fecha_publicacion'], how='left')
df_datos_priori
# Out:
#                                           nombre_video  fecha_publicacion  \
# 0        CÓMO VECTORIZAR PAISAJES_ Tutorial práctico           20210722
# 1    CorelDRAW MAGIC ››Text EFFECT‹‹ 🌟 TIPS Tutorial ▶           20210902
# 2    Cómo CONVERTIR CLIPS DE VIDEO a GIF ANIMADOS ...           20210601
# 3    Cómo CREAR una TARJETA de NEGOCIOS VIRTUAL 💳 ...           20210525
# 4    Estas son las ÚLTIMAS NOVEDADES de COREL DRAW...           20220427
# ..                                                 ...                ...
# 101  🧐 La TABLETA GRÁFICA más BARATA y VENDIDA ¿M...           20211111
# 102  🧐 PRESTA mucha ATENCIÓN a estos DETALLES para...           20220120
# 103  🧐 Sigue ESTE ORDEN en tus PROYECTOS ⭐ para CRE...           20220303
# 104  🧐 Te ENSEÑO estas TÉCNICAS de DIBUJO para DI...           20211109
# 105  🧩 EASY ▶ASSEMBLY◀ Techniques for Beginners & E...           20210914
#
#      visualizaciones  tiempo_de_visualizacion_(horas)  suscriptores  \
# ...

# %%
df_priori.head()
# Out:
#                                nombre_video_original nombre_video  \
# 0       💚Herramienta DIBUJO en Corel DRAW ▶ TUTORIAL          NaN
# 1  💚 TODO sobre la herramienta CURVA en CorelDRAW...          NaN
# 2  🏃🏼‍♂️ Speedrun LOGO CANGREJO #shorts ▶ DelcaVi...          NaN
# 3  ⭐ Haz tus DISEÑOS con PROPORCIÓN ÁUERA ▶ Tutor...          NaN
# 4  💚 La herramienta ZOOM Explicada ▶ TUTORIAL Cor...          NaN
#
#                                         info_videos duracion_video  \
# 0        5 días 8 minutos y 50 segundos 784 visitas       00:08:50
# 1  2 semanas 14 minutos y 11 segundos 2,127 visitas       00:14:11
# 2       3 semanas 1 minuto y 5 segundos 368 visitas       00:01:05
# 3  3 semanas 10 minutos y 55 segundos 1,028 visitas       00:10:55
# 4         1 mes 7 minutos y 24 segundos 759 visitas       00:07:24
#
#                                     page_links           id  \
# 0  https://www.youtube.com/watch?v=cZUmPLANTy0  cZUmPLANTy0
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7377d29e-ada8-4781-9a6b-60a54a1f06a0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
